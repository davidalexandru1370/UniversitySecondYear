# %% [markdown]
# ## A.I. Assignment 5
#
# ## Learning Goals
#
# By the end of this lab, you should be able to:
# * Get more familiar with tensors in pytorch
# * Create a simple multilayer perceptron model with pytorch
# * Visualise the parameters
#
#
# ### Task
#
# Build a fully connected feed forward network that adds two bits. Determine the a propper achitecture for this network (what database you use for this problem? how many layers? how many neurons on each layer? what is the activation function? what is the loss function? etc)
#
# Create at least 3 such networks and compare their performance (how accurate they are?, how farst they are trained to get at 1 accuracy?)
#
# Display for the best one the weights for each layer.

# %%
import torch
import torch.nn as nn
from collections import OrderedDict
from datetime import datetime

data_in = torch.tensor([[0, 0],[1, 0],[0, 1],[1, 1]], dtype=torch.float32)
data_out = torch.tensor([[0, 0], [0, 1], [0, 1], [1, 0]], dtype=torch.float32)

print("data in = ", data_in)
print("data out = ", data_out)

model = nn.Sequential(OrderedDict([
    ('hidden', nn.Linear(2,13)),
    ('leakyRelu', nn.LeakyReLU()),
    ('output', nn.Linear(13,2)),
    ('sigmoid', nn.Sigmoid())
]))

print("model = ", model)

criterion = nn.MSELoss()
optimizer = torch.optim.SGD(model.parameters(), lr = 0.4)
start_time = datetime.now()
stop_time = None

for epoch in range(10000):
    optimizer.zero_grad()
    output = model(data_in)
    loss = criterion(output, data_out)
    loss.backward()
    optimizer.step()
    predicted_list = torch.round(output)
    correct = (predicted_list == data_out).sum()
    if correct >= 0.99 and stop_time == None:
        stop_time = datetime.now()
    if (epoch + 1) % 1000 == 0:
        print(f'Epoch {epoch+1}/{10000} with loss =  {loss.item():.4f}')
        

#print(output)
predicted_list = torch.round(output)
#print(predicted_list == data_out)
correct = (predicted_list == data_out).sum()
accuracy = correct / (len(data_out) * 2)
print("Accuracy is = ", accuracy.item())

if accuracy == 1.0:
    start_time = datetime.strptime(start_time.strftime("%H:%M:%S:%f"),"%H:%M:%S:%f")
    stop_time = datetime.strptime(stop_time.strftime("%H:%M:%S:%f"),"%H:%M:%S:%f")
    print("Total time = ", stop_time - start_time)
    
print("Weights:")
index:int = 0
#print(model)
for name,param in model.named_parameters():
    if param.requires_grad:
        print("Layer ", index)
        print(name,param.data)
        index += 1
# Out:
# data in =  tensor([[0., 0.],
#         [1., 0.],
#         [0., 1.],
#         [1., 1.]])
# data out =  tensor([[0., 0.],
#         [0., 1.],
#         [0., 1.],
#         [1., 0.]])
# model =  Sequential(
#   (hidden): Linear(in_features=2, out_features=13, bias=True)
#   (leakyRelu): LeakyReLU(negative_slope=0.01)
#   (output): Linear(in_features=13, out_features=2, bias=True)
#   (sigmoid): Sigmoid()
# )
# Epoch 1000/10000 with loss =  0.0023
# Epoch 2000/10000 with loss =  0.0006
# Epoch 3000/10000 with loss =  0.0004
# Epoch 4000/10000 with loss =  0.0002
# Epoch 5000/10000 with loss =  0.0002
# Epoch 6000/10000 with loss =  0.0001
# Epoch 7000/10000 with loss =  0.0001
# Epoch 8000/10000 with loss =  0.0001
# Epoch 9000/10000 with loss =  0.0001
# Epoch 10000/10000 with loss =  0.0001
# Accuracy is =  1.0
# Total time =  0:00:00.001383
# Weights:
# Layer  0
# hidden.weight tensor([[-0.3646,  0.6191],
#         [ 1.0398,  1.0369],
#         [-0.5243,  0.1566],
# ...

# %%
import torch
import torch.nn as nn
from collections import OrderedDict

data_in = torch.tensor([[0, 0],[1, 0],[0, 1],[1, 1]], dtype=torch.float32)
data_out = torch.tensor([[0, 0], [0, 1], [0, 1], [1, 0]], dtype=torch.float32)

print("data in = ", data_in)
print("data out = ", data_out)

model = nn.Sequential(OrderedDict([
    ('hidden', nn.Linear(2,4)),
    ('tanh', nn.Tanh()),
    ('output', nn.Linear(4,2)),
    ('sigmoid', nn.Sigmoid())
]))

print("model = ", model)

criterion = nn.BCELoss()
optimizer = torch.optim.SGD(model.parameters(), lr = 0.4)
start_time = datetime.now()
stop_time = None

for epoch in range(10000):
    output = model(data_in)
    loss = criterion(output, data_out)
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()
    predicted_list = torch.round(output)
    correct = (predicted_list == data_out).sum()
    accuracy = correct / (len(data_out) * 2)
    if accuracy == 1.0 and stop_time == None:
        stop_time = datetime.now()
    if (epoch + 1) % 1000 == 0:
        print(f'Epoch {epoch+1}/{1000} with loss =  {loss.item():.4f}')

#print(output)
predicted_list = torch.round(output)
#print(predicted_list == data_out)
accuracy = (correct / (len(data_out) * 2)).item()
print("Accuracy is = ", accuracy * 100, "%")
if accuracy == 1.0:
    start_time = datetime.strptime(start_time.strftime("%H:%M:%S:%f"),"%H:%M:%S:%f")
    stop_time = datetime.strptime(stop_time.strftime("%H:%M:%S:%f"),"%H:%M:%S:%f")
    print("Total time = ", stop_time - start_time, " ms")
    

print("Weights:")
index:int = 0
for name,param in model.named_parameters():
    if param.requires_grad:
        print("Layer ", index)
        print(name,param.data)
        index += 1
# Out:
# data in =  tensor([[0., 0.],
#         [1., 0.],
#         [0., 1.],
#         [1., 1.]])
# data out =  tensor([[0., 0.],
#         [0., 1.],
#         [0., 1.],
#         [1., 0.]])
# model =  Sequential(
#   (hidden): Linear(in_features=2, out_features=4, bias=True)
#   (tanh): Tanh()
#   (output): Linear(in_features=4, out_features=2, bias=True)
#   (sigmoid): Sigmoid()
# )
# Epoch 1000/1000 with loss =  0.0100
# Epoch 2000/1000 with loss =  0.0041
# Epoch 3000/1000 with loss =  0.0025
# Epoch 4000/1000 with loss =  0.0018
# Epoch 5000/1000 with loss =  0.0014
# Epoch 6000/1000 with loss =  0.0012
# Epoch 7000/1000 with loss =  0.0010
# Epoch 8000/1000 with loss =  0.0009
# Epoch 9000/1000 with loss =  0.0008
# Epoch 10000/1000 with loss =  0.0007
# Accuracy is =  100.0 %
# Total time =  0:00:00.084742  ms
# Weights:
# Layer  0
# hidden.weight tensor([[-1.6876,  1.5900],
#         [-3.9734, -3.2598],
#         [ 2.8223,  3.2320],
#         [ 2.2388,  2.5892]])
# Layer  1
# ...

# %%
import torch
import torch.nn as nn
from collections import OrderedDict

data_in = torch.tensor([[0, 0],[1, 0],[0, 1],[1, 1]], dtype=torch.float32)
data_out = torch.tensor([[0, 0],w [0, 1], [0, 1], [1, 0]], dtype=torch.float32)

print("data in = ", data_in)
print("data out = ", data_out)

model = nn.Sequential(OrderedDict([
    ('hidden', nn.Linear(2,6)),
    ('relu', nn.ReLU()),
    ('output', nn.Linear(6,2)),
    ('sigmoid', nn.Sigmoid())
]))

print("model = ", model)

criterion = nn.BCELoss()
optimizer = torch.optim.SGD(model.parameters(), lr = 0.25)
start_time = datetime.now()
stop_time = None

for epoch in range(10000):
    output = model(data_in)
    loss = criterion(output, data_out)
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()
    predicted_list = torch.round(output)
    correct = (predicted_list == data_out).sum()
    accuracy = correct / (len(data_out) * 2)
    if accuracy == 1.0 and stop_time == None:
        stop_time = datetime.now()
    if (epoch + 1) % 1000 == 0:
        print(f'Epoch {epoch+1}/{10000} with loss =  {loss.item():.4f}')

#print(output)
predicted_list = torch.round(output)
#print(predicted_list == data_out)
correct = (predicted_list == data_out).sum()
accuracy = correct / (len(data_out) * 2)
print("Accuracy is = ", accuracy.item())

if accuracy == 1.0:
    start_time = datetime.strptime(start_time.strftime("%H:%M:%S:%f"),"%H:%M:%S:%f")
    stop_time = datetime.strptime(stop_time.strftime("%H:%M:%S:%f"),"%H:%M:%S:%f")
    print("Total time = ", stop_time - start_time)

print("Weights:")
index:int = 0
for name,param in model.named_parameters():
    if param.requires_grad:
        print("Layer ", index)
        print(name,param.data)
        index += 1
# Out:
# data in =  tensor([[0., 0.],
#         [1., 0.],
#         [0., 1.],
#         [1., 1.]])
# data out =  tensor([[0., 0.],
#         [0., 1.],
#         [0., 1.],
#         [1., 0.]])
# model =  Sequential(
#   (hidden): Linear(in_features=2, out_features=6, bias=True)
#   (relu): ReLU()
#   (output): Linear(in_features=6, out_features=2, bias=True)
#   (sigmoid): Sigmoid()
# )
# Epoch 1000/10000 with loss =  0.0057
# Epoch 2000/10000 with loss =  0.0020
# Epoch 3000/10000 with loss =  0.0012
# Epoch 4000/10000 with loss =  0.0008
# Epoch 5000/10000 with loss =  0.0006
# Epoch 6000/10000 with loss =  0.0005
# Epoch 7000/10000 with loss =  0.0004
# Epoch 8000/10000 with loss =  0.0003
# Epoch 9000/10000 with loss =  0.0003
# Epoch 10000/10000 with loss =  0.0003
# Accuracy is =  1.0
# Total time =  0:00:00.072678
# Weights:
# Layer  0
# hidden.weight tensor([[-1.8035, -1.8035],
#         [ 3.1704, -3.2803],
#         [-1.8288,  1.8272],
#         [-2.8352,  2.8352],
# ...

# %%
# your code here
#data_in = torch.tensor( ...
print(data_in)

# %%
# your code here
# data_target = torch.tensor( ...
print(data_target)

# %%
# your code here
# criterion = 
# optimizer =

# %%
# your code here
# Train the model

# %%
# your code here
# visualize the resuts

# %%
# your code here
# print model wights
